# %%
import random
import pandas as pd
import numpy as np

# %% [markdown]
# Ejercicio 1

# %%
numeros= [random.randint(1,25) for i in range(8
                                             )]

# %%
numeros
# Out:
# [16, 18, 4, 5, 15, 23, 3, 17]

# %%
numeros = np.array((6, 1, 20, 14, 23, 8, 3, 24))

# %%
numeros.dtype
# Out:
# dtype('int32')

# %%
numeros.shape
# Out:
# (8,)

# %% [markdown]
# Ejercicio 2

# %%
numeros.mean()
# Out:
# 12.375

# %%
numeros - 12.375
# Out:
# array([ -6.375, -11.375,   7.625,   1.625,  10.625,  -4.375,  -9.375,
#         11.625])

# %% [markdown]
# Ejercicio 3

# %%
numeros2 = np.array(([0,5,10,11,12], [15,20,25,26,27], [30,35,40,41,42],[45,50,55,56,57],[60,65,70,71,72
                                                                                         ]))

# %%
numeros2
# Out:
# array([[ 0,  5, 10, 11, 12],
#        [15, 20, 25, 26, 27],
#        [30, 35, 40, 41, 42],
#        [45, 50, 55, 56, 57],
#        [60, 65, 70, 71, 72]])

# %%
numeros2.shape
# Out:
# (5, 5)

# %%
numeros2.max()
# Out:
# 72

# %%
numeros2.max(axis=0)
# Out:
# array([60, 65, 70, 71, 72])

# %%
numeros2.max(axis=1)
# Out:
# array([12, 27, 42, 57, 72])

# %% [markdown]
# Ejercicio 4

# %%
a = np.repeat((0, 10, 20, 30), 3).reshape(4, 3)
b = np.repeat((0, 1, 2), 4).reshape(3,4).T

# %%
print(a)
# Out:
# [[ 0  0  0]
#  [10 10 10]
#  [20 20 20]
#  [30 30 30]]

# %%
print(b)
# Out:
# [[0 1 2]
#  [0 1 2]
#  [0 1 2]
#  [0 1 2]]

# %%
print(a + b)
# Out:
# [[ 0  1  2]
#  [10 11 12]
#  [20 21 22]
#  [30 31 32]]

# %% [markdown]
# Ejercicio 5

# %%
numeros3=print(a[1:])
# Out:
# [[10 10 10]
#  [20 20 20]
#  [30 30 30]]

# %%
numeros4=print(a[:-1])
# Out:
# [[ 0  0  0]
#  [10 10 10]
#  [20 20 20]]

# %%
d=print(a[3])
# Out:
# [30 30 30]

# %%
e=print(a[:,0])
# Out:
# [ 0 10 20 30]

# %%
d = np.array([30, 30, 30])
e = np.array([0, 10, 20, 30])

# %%
e = np.repeat((0, 10, 20, 30), 3).reshape(4, 3)
d = np.repeat((30, 30, 30), 4).reshape(3,4).T

# %%
f = e + d

# %%
f
# Out:
# array([[30, 30, 30],
#        [40, 40, 40],
#        [50, 50, 50],
#        [60, 60, 60]])

# %% [markdown]
# Ejercicio 6

# %%
import numpy.ma as ma

# %%
f
# Out:
# array([[30, 30, 30],
#        [40, 40, 40],
#        [50, 50, 50],
#        [60, 60, 60]])

# %%
f /4
# Out:
# array([[ 7.5,  7.5,  7.5],
#        [10. , 10. , 10. ],
#        [12.5, 12.5, 12.5],
#        [15. , 15. , 15. ]])

# %%
f == float
# Out:
# array([[False, False, False],
#        [False, False, False],
#        [False, False, False],
#        [False, False, False]])

# %%
f[f == float]
# Out:
# array([], dtype=int32)

# %% [markdown]
# Ejercicio 7. como no he sabido sacar los valores enteros, no puedo realizarlo.

# %% [markdown]
# Ejercicio 8

# %%
import matplotlib.image as mpimg
from PIL import Image 
import matplotlib.pyplot as plt

# %%
I = Image.open("cat.jpg")

# %%
I.show()

# %%
print(I.size, I.mode, I.format)
# Out:
# (600, 599) RGB JPEG

# %%
I1=I.convert('L') # convierte a escala de grises
print (I1.mode)
# Out:
# L

# %%
a=np.asarray(I,dtype=np.float32)

# %%
a
# Out:
# array([[[214., 208., 172.],
#         [215., 209., 175.],
#         [216., 210., 176.],
#         ...,
#         [231., 223., 210.],
#         [232., 222., 210.],
#         [232., 222., 210.]],
#
#        [[214., 208., 172.],
#         [215., 209., 175.],
#         [216., 210., 176.],
#         ...,
#         [231., 223., 210.],
#         [232., 222., 210.],
#         [232., 222., 210.]],
#
#        [[214., 208., 172.],
#         [215., 209., 173.],
#         [216., 210., 176.],
#         ...,
#         [233., 223., 211.],
#         [233., 223., 211.],
#         [232., 222., 210.]],
#
#        ...,
#
#        [[185., 155., 119.],
#         [187., 157., 121.],
#         [189., 159., 123.],
#         ...,
#         [225., 213., 197.],
#         [225., 213., 197.],
#         [224., 212., 196.]],
#
#        [[183., 153., 119.],
#         [185., 155., 121.],
#         [187., 157., 123.],
#         ...,
#         [226., 214., 198.],
#         [225., 213., 197.],
# ...

# %%
una_parte=a[251:283,317:349]

# %%
una_parte
# Out:
# array([[[158., 129.,  95.],
#         [147., 118.,  86.],
#         [159., 130.,  98.],
#         ...,
#         [178., 145., 100.],
#         [182., 149., 106.],
#         [179., 146., 103.]],
#
#        [[163., 134., 102.],
#         [149., 123.,  90.],
#         [154., 127.,  97.],
#         ...,
#         [177., 144.,  99.],
#         [179., 146., 103.],
#         [191., 158., 117.]],
#
#        [[176., 150., 117.],
#         [175., 148., 118.],
#         [179., 152., 122.],
#         ...,
#         [168., 135.,  90.],
#         [157., 124.,  81.],
#         [176., 143., 102.]],
#
#        ...,
#
#        [[141.,  92.,  49.],
#         [145.,  96.,  53.],
#         [162., 113.,  70.],
#         ...,
#         [181., 142., 101.],
#         [140., 101.,  58.],
#         [154., 112.,  70.]],
#
#        [[152., 101.,  58.],
#         [150.,  99.,  56.],
#         [134.,  83.,  40.],
#         ...,
#         [145., 106.,  65.],
#         [158., 119.,  78.],
# ...

# %%
plt.imshow(I)
plt.show()

# %%
from skimage import io

# %%
image=io.imread("cat.jpg")/255.0

# %%
print("- Dimensiones de la imagen:")
print(image.shape)
plt.imshow(image,vmin=0,vmax=1)
# Out:
# - Dimensiones de la imagen:
# (599, 600, 3)

# %%
plt.imshow(image[:,:,0],vmin=0,vmax=1)
plt.title("Canal Rojo")
plt.figure()
plt.imshow(image[:,:,1],vmin=0,vmax=1)
plt.title("Canal Verde")
plt.figure()
plt.imshow(image[:,:,2],vmin=0,vmax=1)
plt.title("Canal Azul")
# Out:
# Text(0.5, 1.0, 'Canal Azul')

# %%
image[:,:,1]=0

plt.title("cat_elimino_verde")
plt.imshow(image)

# %%
image[:,:,2]=0

plt.title("cat_elimino_azul")
plt.imshow(image)

# %%
import matplotlib.image as mpimg

# %%
mpimg.imsave('cat_elimino_azul.jpg',image)

# %%
mpimg.imsave('cat_elimino_verde.jpg',image)
